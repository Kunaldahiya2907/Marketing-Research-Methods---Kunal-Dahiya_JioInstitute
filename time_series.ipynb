# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunaldahiya2907/Marketing-Research-Methods---Kunal-Dahiya_JioInstitute/blob/main/time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# Load the dataset
file_path = "/content/Superstore - store analysis.csv"  # Update with your file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Aggregate sales by date
df_ts = df.groupby('Order Date')['Sales'].sum().reset_index()

# Rename columns for Prophet compatibility
df_ts.columns = ['ds', 'y']

# Initialize and fit the Prophet model
model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=False)
model.fit(df_ts)

# Create future dataframe for prediction (next 365 days)
future = model.make_future_dataframe(periods=365)

# Predict sales
forecast = model.predict(future)

# Plot forecast
fig1 = model.plot(forecast)
plt.title("Sales Forecast using Prophet")
plt.show()

# Plot components to analyze trends and seasonality
fig2 = model.plot_components(forecast)
plt.show()
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5ehouxyr/01t9ndlv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5ehouxyr/3d_6crz5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62347', 'data', 'file=/tmp/tmp5ehouxyr/01t9ndlv.json', 'init=/tmp/tmp5ehouxyr/3d_6crz5.json', 'output', 'file=/tmp/tmp5ehouxyr/prophet_modelgh_666wi/prophet_model-20250205073833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:38:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:38:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# Step 1: Load and Clean Data
file_path = "/content/Superstore - store analysis.csv"  # Update with your file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Drop rows with missing dates
df = df.dropna(subset=['Order Date'])

# Aggregate sales by date
df_ts = df.groupby('Order Date')['Sales'].sum().reset_index()

# Rename columns for Prophet compatibility
df_ts.columns = ['ds', 'y']

# Step 2: Fit Prophet Model
model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=False)
model.fit(df_ts)

# Step 3: Create Future Dates and Forecast
future = model.make_future_dataframe(periods=365)  # Forecast for next 365 days
forecast = model.predict(future)

# Step 4: Plot Forecast
fig1 = model.plot(forecast)
plt.title("Sales Forecast using Prophet")
plt.show()

# Step 5: Plot Seasonal Trends
fig2 = model.plot_components(forecast)
plt.show()
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5ehouxyr/_czv27d0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5ehouxyr/_s_i9l24.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12144', 'data', 'file=/tmp/tmp5ehouxyr/_czv27d0.json', 'init=/tmp/tmp5ehouxyr/_s_i9l24.json', 'output', 'file=/tmp/tmp5ehouxyr/prophet_modelxgy_nt13/prophet_model-20250205073950.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:39:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:39:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet

# Step 1: Load and Clean Data
file_path = "/content/Superstore - store analysis.csv"  # Update with your file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Drop rows with missing dates
df = df.dropna(subset=['Order Date'])

# Aggregate sales by date
df_ts = df.groupby('Order Date')['Sales'].sum().reset_index()

# Rename columns for Prophet compatibility
df_ts.columns = ['ds', 'y']

# Step 2: Moving Average for Smoother Trend Analysis
df_ts['MA_30'] = df_ts['y'].rolling(window=30).mean()  # 30-day moving average

# Step 3: Prophet Model Training
model = Prophet(yearly_seasonality=True, weekly_seasonality=True, daily_seasonality=False)
model.fit(df_ts)

# Step 4: Future Prediction
future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)

# Step 5: Enhanced Visualizations

# 1. Sales Trend with Moving Average
plt.figure(figsize=(12,6))
plt.plot(df_ts['ds'], df_ts['y'], label="Daily Sales", alpha=0.5)
plt.plot(df_ts['ds'], df_ts['MA_30'], label="30-Day Moving Average", color='red', linewidth=2)
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Sales Trend with 30-Day Moving Average")
plt.legend()
plt.grid()
plt.show()

# 2. Forecast with Prophet
fig1 = model.plot(forecast)
plt.title("Sales Forecast using Prophet")
plt.show()

# 3. Prophet Components: Trend & Seasonality
fig2 = model.plot_components(forecast)
plt.show()

# 4. Year-over-Year Growth
df_ts['Year'] = df_ts['ds'].dt.year
yoy_growth = df_ts.groupby('Year')['y'].sum().pct_change() * 100  # YoY % Growth

plt.figure(figsize=(8,5))
sns.barplot(x=yoy_growth.index.astype(str), y=yoy_growth.values, palette="Blues_d")
plt.xlabel("Year")
plt.ylabel("YoY Growth (%)")
plt.title("Year-over-Year Sales Growth")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# 5. Monthly Seasonality Boxplot
df_ts['Month'] = df_ts['ds'].dt.month

plt.figure(figsize=(10,6))
sns.boxplot(x=df_ts['Month'], y=df_ts['y'], palette="coolwarm")
plt.xlabel("Month")
plt.ylabel("Sales Distribution")
plt.title("Monthly Sales Seasonality")
plt.show()

# 6. Weekly Seasonality Boxplot
df_ts['Weekday'] = df_ts['ds'].dt.day_name()

plt.figure(figsize=(10,6))
sns.boxplot(x=df_ts['Weekday'], y=df_ts['y'], order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], palette="viridis")
plt.xlabel("Day of the Week")
plt.ylabel("Sales Distribution")
plt.title("Weekly Sales Seasonality")
plt.show()
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5ehouxyr/3pu3bz1k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5ehouxyr/xxm_9s3f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6866', 'data', 'file=/tmp/tmp5ehouxyr/3pu3bz1k.json', 'init=/tmp/tmp5ehouxyr/xxm_9s3f.json', 'output', 'file=/tmp/tmp5ehouxyr/prophet_modelro309xaj/prophet_model-20250205074134.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:41:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:41:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-3-33054a300378>:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load Data
file_path = "/content/Superstore - store analysis.csv"  # Update with your file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Drop rows with missing dates
df = df.dropna(subset=['Order Date'])

# Extract hour of the day
df['Hour'] = df['Order Date'].dt.hour

# Step 2: Aggregate sales by hour
hourly_sales = df.groupby('Hour')['Sales'].sum().reset_index()

# Step 3: Plot hourly sales trend
plt.figure(figsize=(12,6))
sns.lineplot(x=hourly_sales['Hour'], y=hourly_sales['Sales'], marker="o", color="b", linewidth=2)
plt.xlabel("Hour of the Day (24-Hour Format)")
plt.ylabel("Total Sales")
plt.title("Sales Trend Over 24 Hours")
plt.xticks(range(0,24))  # Ensure x-axis has all hours
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Step 1: Load Data
file_path = "/content/Superstore - store analysis.csv"  # Update with your file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
np.random.seed(42)  # For reproducibility
df['Hour'] = np.random.choice(
    [i for i in range(24)], size=len(df), p=[
        0.05, 0.05, 0.05, 0.05, 0.05, 0.05,  # 12 AM - 6 AM (Night)
        0.10, 0.10, 0.10, 0.10, 0.10, 0.10,  # 6 AM - 12 PM (Morning)
        0.15, 0.15, 0.15, 0.15, 0.10, 0.10,  # 12 PM - 6 PM (Afternoon)
        0.10, 0.10, 0.10, 0.10, 0.05, 0.05   # 6 PM - 12 AM (Evening)
    ])

# Step 3: Categorize Hours into Time Periods
def categorize_time(hour):
    if 0 <= hour < 6:
        return "Night"
    elif 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    else:
        return "Evening"

df['Time Period'] = df['Hour'].apply(categorize_time)

# Step 4: Aggregate Data
order_counts = df['Time Period'].value_counts()
sales_by_period = df.groupby('Time Period')['Sales'].sum().sort_values(ascending=False)

# Step 5: Plot Orders by Time Period (Pie Chart)
plt.figure(figsize=(8, 6))
plt.pie(order_counts, labels=order_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title("Order Distribution Across Time Periods")
plt.show()

# Step 6: Plot Sales by Time Period (Bar Chart)
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
plt.xlabel("Time Period")
plt.ylabel("Total Sales")
plt.title("Total Sales Across Time Periods")
plt.show()

# Step 7: Display Aggregated Data
import ace_tools as tools
tools.display_dataframe_to_user(name="Sales & Orders by Time Period", dataframe=sales_by_period.reset_index())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-64eab72c2480> in <cell line: 0>()
#      13 # Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
#      14 np.random.seed(42)  # For reproducibility
# ---> 15 df['Hour'] = np.random.choice(
#      16     [i for i in range(24)], size=len(df), p=[
#      17         0.05, 0.05, 0.05, 0.05, 0.05, 0.05,  # 12 AM - 6 AM (Night)
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Step 1: Load Data
file_path = "/content/Superstore - store analysis.csv"  # Update with your file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
np.random.seed(42)  # For reproducibility
df['Hour'] = np.random.choice(
    [i for i in range(24)], size=len(df), p=[
        0.04, 0.04, 0.03, 0.03, 0.03, 0.03,  # 12 AM - 6 AM (Night) = 20%
        0.08, 0.08, 0.08, 0.08, 0.08, 0.08,  # 6 AM - 12 PM (Morning) = 24%
        0.12, 0.12, 0.12, 0.12, 0.08, 0.08,  # 12 PM - 6 PM (Afternoon) = 24%
        0.07, 0.07, 0.07, 0.07, 0.03, 0.03   # 6 PM - 12 AM (Evening) = 20%
    ])

# Step 3: Categorize Hours into Time Periods
def categorize_time(hour):
    if 0 <= hour < 6:
        return "Night"
    elif 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    else:
        return "Evening"

df['Time Period'] = df['Hour'].apply(categorize_time)

# Step 4: Aggregate Data
order_counts = df['Time Period'].value_counts()
sales_by_period = df.groupby('Time Period')['Sales'].sum().sort_values(ascending=False)

# Step 5: Plot Orders by Time Period (Pie Chart)
plt.figure(figsize=(8, 6))
plt.pie(order_counts, labels=order_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title("Order Distribution Across Time Periods")
plt.show()

# Step 6: Plot Sales by Time Period (Bar Chart)
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
plt.xlabel("Time Period")
plt.ylabel("Total Sales")
plt.title("Total Sales Across Time Periods")
plt.show()

# Step 7: Display Aggregated Data
import ace_tools as tools
tools.display_dataframe_to_user(name="Sales & Orders by Time Period", dataframe=sales_by_period.reset_index())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-51ba8cc4b6bf> in <cell line: 0>()
#      13 # Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
#      14 np.random.seed(42)  # For reproducibility
# ---> 15 df['Hour'] = np.random.choice(
#      16     [i for i in range(24)], size=len(df), p=[
#      17         0.04, 0.04, 0.03, 0.03, 0.03, 0.03,  # 12 AM - 6 AM (Night) = 20%
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Step 1: Load Data
file_path = "/content/Superstore - store analysis.csv"  # Correct file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
np.random.seed(42)  # For reproducibility

# Corrected probabilities (sum = 1.0)
hour_probabilities = [
    0.04, 0.04, 0.03, 0.03, 0.03, 0.03,  # 12 AM - 6 AM (Night) = 20%
    0.08, 0.08, 0.08, 0.08, 0.08, 0.08,  # 6 AM - 12 PM (Morning) = 24%
    0.12, 0.12, 0.12, 0.12, 0.08, 0.08,  # 12 PM - 6 PM (Afternoon) = 24%
    0.07, 0.07, 0.07, 0.07, 0.04, 0.04   # 6 PM - 12 AM (Evening) = 20%
]

# Ensure probabilities sum to exactly 1
hour_probabilities[-1] += 1.0 - sum(hour_probabilities)

df['Hour'] = np.random.choice(range(24), size=len(df), p=hour_probabilities)

# Step 3: Categorize Hours into Time Periods
def categorize_time(hour):
    if 0 <= hour < 6:
        return "Night"
    elif 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    else:
        return "Evening"

df['Time Period'] = df['Hour'].apply(categorize_time)

# Step 4: Aggregate Data
order_counts = df['Time Period'].value_counts()
sales_by_period = df.groupby('Time Period')['Sales'].sum().sort_values(ascending=False)

# Step 5: Plot Orders by Time Period (Pie Chart)
plt.figure(figsize=(8, 6))
plt.pie(order_counts, labels=order_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title("Order Distribution Across Time Periods")
plt.show()

# Step 6: Plot Sales by Time Period (Bar Chart)
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
plt.xlabel("Time Period")
plt.ylabel("Total Sales")
plt.title("Total Sales Across Time Periods")
plt.show()

# Step 7: Display Aggregated Data
import ace_tools as tools
tools.display_dataframe_to_user(name="Sales & Orders by Time Period", dataframe=sales_by_period.reset_index())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-bc2ce033f2ed> in <cell line: 0>()
#      25 hour_probabilities[-1] += 1.0 - sum(hour_probabilities)
#      26
# ---> 27 df['Hour'] = np.random.choice(range(24), size=len(df), p=hour_probabilities)
#      28
#      29 # Step 3: Categorize Hours into Time Periods
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities are not non-negative

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Step 1: Load Data
file_path = "/content/Superstore - store analysis.csv"  # Correct file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
np.random.seed(42)  # For reproducibility

# Corrected probabilities (sum = 1.0 and all positive)
hour_probabilities = [
    0.05, 0.05, 0.04, 0.04, 0.03, 0.03,  # 12 AM - 6 AM (Night) = 24%
    0.08, 0.08, 0.08, 0.08, 0.08, 0.08,  # 6 AM - 12 PM (Morning) = 24%
    0.12, 0.12, 0.12, 0.12, 0.08, 0.08,  # 12 PM - 6 PM (Afternoon) = 24%
    0.07, 0.07, 0.07, 0.07, 0.03, 0.03   # 6 PM - 12 AM (Evening) = 24%
]

df['Hour'] = np.random.choice(range(24), size=len(df), p=hour_probabilities)

# Step 3: Categorize Hours into Time Periods
def categorize_time(hour):
    if 0 <= hour < 6:
        return "Night"
    elif 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    else:
        return "Evening"

df['Time Period'] = df['Hour'].apply(categorize_time)

# Step 4: Aggregate Data
order_counts = df['Time Period'].value_counts()
sales_by_period = df.groupby('Time Period')['Sales'].sum().sort_values(ascending=False)

# Step 5: Plot Orders by Time Period (Pie Chart)
plt.figure(figsize=(8, 6))
plt.pie(order_counts, labels=order_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title("Order Distribution Across Time Periods")
plt.show()

# Step 6: Plot Sales by Time Period (Bar Chart)
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
plt.xlabel("Time Period")
plt.ylabel("Total Sales")
plt.title("Total Sales Across Time Periods")
plt.show()

# Step 7: Display Aggregated Data
import ace_tools as tools
tools.display_dataframe_to_user(name="Sales & Orders by Time Period", dataframe=sales_by_period.reset_index())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-8dc8ff60351b> in <cell line: 0>()
#      22 ]
#      23
# ---> 24 df['Hour'] = np.random.choice(range(24), size=len(df), p=hour_probabilities)
#      25
#      26 # Step 3: Categorize Hours into Time Periods
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Step 1: Load Data
file_path = "/content/Superstore - store analysis.csv"  # Update with correct file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
np.random.seed(42)  # Ensures reproducibility

# Corrected probabilities that sum to exactly 1.0
hour_probabilities = np.array([
    0.05, 0.05, 0.04, 0.04, 0.03, 0.03,  # 12 AM - 6 AM (Night) = 24%
    0.08, 0.08, 0.08, 0.08, 0.08, 0.08,  # 6 AM - 12 PM (Morning) = 24%
    0.12, 0.12, 0.12, 0.12, 0.08, 0.08,  # 12 PM - 6 PM (Afternoon) = 24%
    0.07, 0.07, 0.07, 0.07, 0.03, 0.03   # 6 PM - 12 AM (Evening) = 24%
])

# Normalize probabilities to exactly sum to 1
hour_probabilities = hour_probabilities / hour_probabilities.sum()

df['Hour'] = np.random.choice(range(24), size=len(df), p=hour_probabilities)

# Step 3: Categorize Hours into Time Periods
def categorize_time(hour):
    if 0 <= hour < 6:
        return "Night"
    elif 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    else:
        return "Evening"

df['Time Period'] = df['Hour'].apply(categorize_time)

# Step 4: Aggregate Data
order_counts = df['Time Period'].value_counts()
sales_by_period = df.groupby('Time Period')['Sales'].sum().sort_values(ascending=False)

# Step 5: Plot Orders by Time Period (Pie Chart)
plt.figure(figsize=(8, 6))
plt.pie(order_counts, labels=order_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title("Order Distribution Across Time Periods")
plt.show()

# Step 6: Plot Sales by Time Period (Bar Chart)
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
plt.xlabel("Time Period")
plt.ylabel("Total Sales")
plt.title("Total Sales Across Time Periods")
plt.show()

# Step 7: Display Aggregated Data
import ace_tools as tools
tools.display_dataframe_to_user(name="Sales & Orders by Time Period", dataframe=sales_by_period.reset_index())
# Out:
# <ipython-input-9-f12f31313c7c>:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-f12f31313c7c> in <cell line: 0>()
#      59
#      60 # Step 7: Display Aggregated Data
# ---> 61 import ace_tools as tools
#      62 tools.display_dataframe_to_user(name="Sales & Orders by Time Period", dataframe=sales_by_period.reset_index())
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Step 1: Load Data
file_path = "/content/Superstore - store analysis.csv"  # Update with correct file path
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Convert 'Order Date' to datetime
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# Step 2: Assign Random Hours to Orders (Simulating Time Distribution)
np.random.seed(42)  # Ensures reproducibility

# Corrected probabilities that sum to exactly 1.0
hour_probabilities = np.array([
    0.05, 0.05, 0.04, 0.04, 0.03, 0.03,  # 12 AM - 6 AM (Night) = 24%
    0.08, 0.08, 0.08, 0.08, 0.08, 0.08,  # 6 AM - 12 PM (Morning) = 24%
    0.12, 0.12, 0.12, 0.12, 0.08, 0.08,  # 12 PM - 6 PM (Afternoon) = 24%
    0.07, 0.07, 0.07, 0.07, 0.03, 0.03   # 6 PM - 12 AM (Evening) = 24%
])

# Normalize probabilities to exactly sum to 1
hour_probabilities = hour_probabilities / hour_probabilities.sum()

df['Hour'] = np.random.choice(range(24), size=len(df), p=hour_probabilities)

# Step 3: Categorize Hours into Time Periods
def categorize_time(hour):
    if 0 <= hour < 6:
        return "Night"
    elif 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    else:
        return "Evening"

df['Time Period'] = df['Hour'].apply(categorize_time)

# Step 4: Aggregate Data
order_counts = df['Time Period'].value_counts()
sales_by_period = df.groupby('Time Period')['Sales'].sum().sort_values(ascending=False)

# Step 5: Plot Orders by Time Period (Pie Chart)
plt.figure(figsize=(8, 6))
plt.pie(order_counts, labels=order_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title("Order Distribution Across Time Periods")
plt.show()

# Step 6: Plot Sales by Time Period (Bar Chart)
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
plt.xlabel("Time Period")
plt.ylabel("Total Sales")
plt.title("Total Sales Across Time Periods")
plt.show()

# Step 7: Display Aggregated Data
print("\n### Sales & Orders by Time Period ###")
print(sales_by_period.reset_index())
# Out:
# <ipython-input-10-c177cb572286>:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_period.index, y=sales_by_period.values, palette="coolwarm")
# ### Sales & Orders by Time Period ###
#   Time Period        Sales
# 0   Afternoon  838832.1574
# 1     Morning  692403.5381
# 2     Evening  422856.4686
# 3       Night  343108.6962
